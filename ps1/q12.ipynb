# %%
using LinearAlgebra
using Convex
using SCS
# Out:
# ┌ Info: Precompiling Convex [f65535da-76fb-5f13-bab9-19810c17039a]
# └ @ Base loading.jl:1278
# ┌ Info: Precompiling SCS [c946c3f1-0d1f-5ce8-9dea-7daa1f7e2d13]
# └ @ Base loading.jl:1278

# %%
function proj(x, v0, v, norm_fn)
    solver = () -> SCS.Optimizer(verbose=0)
    y = Variable(2)
    t = Variable()
    p = minimize(norm_fn(x - y), y == t * v + v0)
    solve!(p, solver)
    return y.value, p.optval
end

v0 = [-2; -4]
v = [-2; 5]
x = [3; 2];

# %%
proj(x, v0, v, norm2)
# Out:
# ([-3.379308580231317; -0.5517197152730516], 6.870728374349656)

# %%
proj(x, v0, v, x -> norm(x, 1))
# Out:
# ([-4.4000000005330495; 2.0000000000497464], 7.40000000098523)

# %%
proj(x, v0, v, x -> maximum(x))
# Out:
# ([-2.2857142854941315; -3.2857142853456933], 5.28571428515518)
